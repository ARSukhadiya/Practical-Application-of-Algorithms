# %% [markdown]
# **Problem1-Leetcode#217-Contains Duplicate-Easy**
#
# Given an integer array nums, return true if any value appears at least twice in the array, and return false if every element is distinct.
#
# - Example 1:
#     - Input: nums = [1,2,3,1]
#     - Output: true
#
# - Example 2:
#     - Input: nums = [1,2,3,4]
#     - Output: false
# - Example 3:
#     - Input: nums = [1,1,1,3,3,4,3,2,4,2]
#     - Output: true

# %%
# function f:
    # Take a Hashmap as `hmap` with key-value pairs
    # Iterate over the nums
        # check if the num is in `hmap`:
            # increase value of hmap[num] to +1
            # return True
        # else
            # add hmap[num] = 1
    # return False

# %% [markdown]
# **Problem2-Leetcode#1-Two Sum-Easy**
#
# Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.
#
# You can return the answer in any order.
#
# - Example 1:
#     - Input: nums = [2,7,11,15], target = 9
#     - Output: [0,1]
#     - Explanation: Because nums[0] + nums[1] == 9, we return [0, 1].
#
# - Example 2:
#     - Input: nums = [3,2,4], target = 6
#     - Output: [1,2]
#
# - Example 3:
#     - Input: nums = [3,3], target = 6
#     - Output: [0,1]

# %%
# function fun(nums, target)
    # Iterate over 0 to len(nums) as element `num_index`:
        # iterate over 0 to len(nums) as element `num2_index`:
            # if num_index == num2_index:
                # continue
            # if nums[num_index] + nums[num2_index] == target:
                # return num_index, num2_index

# %% [markdown]
# **Problem3-Leetcode#146-LRU Cache-Medium**
#
# Design a data structure that follows the constraints of a Least Recently Used (LRU) cache.
#
# Implement the LRUCache class:
#
# LRUCache(int capacity) Initialize the LRU cache with positive size capacity.\
# int get(int key) Return the value of the key if the key exists, otherwise return -1.\
# void put(int key, int value) Update the value of the key if the key exists. Otherwise,\
# add the key-value pair to the cache. If the number of keys exceeds the capacity from \
# this operation, evict the least recently used key.
#
# The functions get and put must each run in O(1) average time complexity.
#
#
#
# - Example 1:
#
#     - Input ["LRUCache", "put", "put", "get", "put", "get", "put", "get", "get", "get"]\
#     [[2], [1, 1], [2, 2], [1], [3, 3], [2], [4, 4], [1], [3], [4]]
#     - Output
#     [null, null, null, 1, null, -1, null, -1, 3, 4]
#
#     - Explanation
#         - LRUCache lRUCache = new LRUCache(2);
#         - lRUCache.put(1, 1); // cache is {1=1}
#         - lRUCache.put(2, 2); // cache is {1=1, 2=2}
#         - lRUCache.get(1);    // return 1
#         - lRUCache.put(3, 3); // LRU key was 2, evicts key 2, cache is {1=1, 3=3}
#         - lRUCache.get(2);    // returns -1 (not found)
#         - lRUCache.put(4, 4); // LRU key was 1, evicts key 1, cache is {4=4, 3=3}
#         - lRUCache.get(1);    // return -1 (not found)
#         - lRUCache.get(3);    // return 3
#         - lRUCache.get(4);    // return 4

# %%
# Use an OrderedDict to store key-value pairs where the keys represent the cache keys and the values are the corresponding values.

# function put(key, value):
    # If the key exists in the cache:
        # Update its value.
        # Move the key to the end of the OrderedDict.
    # If the key does not exist:
        # Add the key-value pair to the OrderedDict.
        # Check if adding this new pair exceeds the capacity.
        # If it does, remove the least recently used item from the OrderedDict.

# function get(key):
    # Retrieve the value associated with the key from the OrderedDict.
    # If the key exists, move it to the end of the OrderedDict to mark it as recently used.
    # If the key does not exist, return -1.

# LRU Mechanism
# Using the OrderedDict, which allows efficient reordering of keys based on access, 
# ensures that the least recently used items are evicted first when the capacity is exceeded.

# %% [markdown]
# **Problem4-Leetcode#705-Design HashSet-Easy**
#
# Design a HashSet without using any built-in hash table libraries.
#
# Implement MyHashSet class:
#
# void add(key) Inserts the value key into the HashSet.\
# bool contains(key) Returns whether the value key exists in the HashSet or not.\
# void remove(key) Removes the value key in the HashSet. If key does not exist in the HashSet, do nothing.\
#
#
# - Example 1:
#
#     - Input["MyHashSet", "add", "add", "contains", "contains", "add", "contains", "remove", "contains"]
#            [[], [1], [2], [1], [3], [2], [2], [2], [2]]
#     - Output [null, null, null, true, false, null, true, null, false]
#
#     - Explanation
#         - MyHashSet myHashSet = new MyHashSet();
#         - myHashSet.add(1);      // set = [1]
#         - myHashSet.add(2);      // set = [1, 2]
#         - myHashSet.contains(1); // return True
#         - myHashSet.contains(3); // return False, (not found)
#         - myHashSet.add(2);      // set = [1, 2]
#         - myHashSet.contains(2); // return True
#         - myHashSet.remove(2);   // set = [1]
#         - myHashSet.contains(2); // return False, (already removed)

# %%
# Hash Function
    # We'll use a simple hash function to map keys to indices in our array. This hash function should distribute keys evenly across the array size.

# Collision Handling
    # Since multiple keys might hash to the same index (collision), each index in our array will contain a linked list of elements.

# Operations
    # Add: 
    # Insert a key into the HashSet. 
    # First, compute the hash of the key to determine the index. 
    # If the key doesn't already exist in the linked list at that index, add it.

    # Contains: 
    # Check if a key exists in the HashSet. 
    # Compute the hash to find the corresponding index and search for the key in the linked list at that index.

    # Remove: 
    # Remove a key from the HashSet if it exists. 
    # Compute the hash to find the index and remove the key from the linked list if found.

# %% [markdown]
# **Problem5-Leetcode#706- Design HashMap-Easy**
#
# Design a HashMap without using any built-in hash table libraries.
#
# Implement the MyHashMap class:
#
# MyHashMap() initializes the object with an empty map.\
# void put(int key, int value) inserts a (key, value) pair into the HashMap.\
# If the key already exists in the map, update the corresponding value.
# int get(int key) returns the value to which the specified key is mapped,\
# or -1 if this map contains no mapping for the key.\
# void remove(key) removes the key and its corresponding value\
# if the map contains the mapping for the key.
#
#
# - Example 1:
#
#     - Input ["MyHashMap", "put", "put", "get", "get", "put", "get", "remove", "get"]\
#           [[], [1, 1], [2, 2], [1], [3], [2, 1], [2], [2], [2]]
#     - Output [null, null, null, 1, -1, null, 1, null, -1]
#
#     - Explanation
#         - MyHashMap myHashMap = new MyHashMap();
#         - myHashMap.put(1, 1); // The map is now [[1,1]]
#         - myHashMap.put(2, 2); // The map is now [[1,1], [2,2]]
#         - myHashMap.get(1);    // return 1, The map is now [[1,1], [2,2]]
#         - myHashMap.get(3);    // return -1 (i.e., not found), The map is now [[1,1], [2,2]]
#         - myHashMap.put(2, 1); // The map is now [[1,1], [2,1]] (i.e., update the existing value)
#         - myHashMap.get(2);    // return 1, The map is now [[1,1], [2,1]]
#         - myHashMap.remove(2); // remove the mapping for 2, The map is now [[1,1]]
#         - myHashMap.get(2);    // return -1 (i.e., not found), The map is now [[1,1]]

# %%
# Hash Function
# We'll use a simple hash function to map keys to indices in our array. 
# This hash function should distribute keys evenly across the array size.

# Collision Handling
# Since multiple keys might hash to the same index (collision), each index in our array will contain a linked list of elements (key-value pairs).

# Operations
    # Put: 
    # Insert a key-value pair into the HashMap. 
    # Compute the hash of the key to determine the index. 
    # If the key already exists in the linked list at that index, update its value. 
    # Otherwise, add a new node (key-value pair) to the linked list.

    # Get: 
    # Retrieve the value associated with a key from the HashMap. 
    # Compute the hash to find the corresponding index and search for the key in the linked list at that index. 
    # Return the value if found, otherwise return -1.

    # Remove: 
    # Remove a key and its corresponding value from the HashMap if it exists. 
    # Compute the hash to find the index and remove the node (key-value pair) from the linked list if found.
